# %%
# Step 1: Import Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import pairwise_distances
import csv
import pandas as pd
from collections import Counter
from sklearn.metrics import normalized_mutual_info_score
from sklearn.cluster import MiniBatchKMeans

# %%
# Step 2: Load my data
def labelmaker(events, e_density, noise, filename = None, folder = None): 
    '''creates labels based on my naming convention for different files, keeps it consistent and easy'''
    if folder: 
        folder = folder + '/'

    if filename: 
        datafile = str(filename) 
    else: 
        datafile = str(events) + 'ev_n' + str(noise) + '_es' + str(int(e_density*100))    

    labelfile = 'labels_' + datafile + '.csv'
    sourcefile = 'sources_' + datafile + '.csv'
    ai_labelfile = datafile + '_AIlabels' + '.csv'
    centroidfile = datafile + '_centroids' + '.csv'
    datafile = datafile + '.csv'

    if folder: 
        datafile = folder + datafile 
        centroidfile = folder + centroidfile 
        ai_labelfile = folder + ai_labelfile 
        labelfile = folder + labelfile 
        sourcefile = folder + sourcefile 

    
    return datafile, labelfile, sourcefile, ai_labelfile, centroidfile


def pull(datafile, labelfile, sourcefile): 
    columns = ['x [px]', 'y [px]', 't [s]', 't_relToExtTrigger [s]']
    
    dataread = pd.read_csv(datafile) 
    all_data = np.array(dataread[columns])
    data = all_data[:,:3]
    
    labelread = pd.read_csv(labelfile)
    labels = np.array(labelread['labels'])
    
    sourceread = pd.read_csv(sourcefile) 
    all_sources = np.array(sourceread[columns])
    sources = all_sources[:,:3]

    return data, labels, sources

# %%
datafile, labelfile, sourcefile, ai_labelfile, centroidfile = labelmaker(1000, 1, 0, filename = '10000ev_mixed_n0', folder = 'big_datasets/formatted_for_empir')
data, labels, sources = pull(datafile, labelfile, sourcefile)
print(datafile)
k = 10000
# Out:
# big_datasets/formatted_for_empir/10000ev_mixed_n0.csv

# %%
kmeans = KMeans(n_clusters = k, init='k-means++', n_init=10, random_state=42, 
                max_iter=500, tol = 0.00001)
kmeans.fit(data)
ai_centroids = kmeans.cluster_centers_
ai_labels = kmeans.labels_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 3
#       1 kmeans = KMeans(n_clusters = k, init='k-means++', n_init=10, random_state=42,
#       2                 max_iter=500, tol = 0.00001)
# ----> 3 kmeans.fit(data)
#       4 ai_centroids = kmeans.cluster_centers_
#       5 ai_labels = kmeans.labels_
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1508, in KMeans.fit(self, X, y, sample_weight)
#    1504 best_inertia, best_labels = None, None
#    1506 for i in range(self._n_init):
#    1507     # Initialize centers
# -> 1508     centers_init = self._init_centroids(
#    1509         X,
#    1510         x_squared_norms=x_squared_norms,
#    1511         init=init,
#    1512         random_state=random_state,
#    1513         sample_weight=sample_weight,
#    1514     )
#    1515     if self.verbose:
#    1516         print("Initialization complete")
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1020, in _BaseKMeans._init_centroids(self, X, x_squared_norms, init, random_state, sample_weight, init_size, n_centroids)
#    1017     sample_weight = sample_weight[init_indices]
#    1019 if isinstance(init, str) and init == "k-means++":
# -> 1020     centers, _ = _kmeans_plusplus(
#    1021         X,
#    1022         n_clusters,
#    1023         random_state=random_state,
#    1024         x_squared_norms=x_squared_norms,
#    1025         sample_weight=sample_weight,
#    1026     )
#    1027 elif isinstance(init, str) and init == "random":
#    1028     seeds = random_state.choice(
#    1029         n_samples,
#    1030         size=n_clusters,
#    1031         replace=False,
#    1032         p=sample_weight / sample_weight.sum(),
#    1033     )
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:258, in _kmeans_plusplus(X, n_clusters, x_squared_norms, sample_weight, random_state, n_local_trials)
#     255 np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)
#     257 # Compute distances to center candidates
# --> 258 distance_to_candidates = _euclidean_distances(
#     259     X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     260 )
#     262 # update closest distances squared and potential for each candidate
#     263 np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:407, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     404     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     405 else:
#     406     # if dtype is already float64, no need to chunk and upcast
# --> 407     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     408     distances += XX
#     409     distances += YY
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/sklearn/utils/extmath.py:208, in safe_sparse_dot(a, b, dense_output)
#     204 else:
#     205     ret = a @ b
#     207 if (
# --> 208     sparse.issparse(a)
#     209     and sparse.issparse(b)
#     210     and dense_output
#     211     and hasattr(ret, "toarray")
#     212 ):
#     213     return ret.toarray()
#     214 return ret
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/scipy/sparse/_base.py:1401, in issparse(x)
#    1395     """A namespace class to separate sparray from spmatrix"""
#    1398 sparray.__doc__ = _spbase.__doc__
# -> 1401 def issparse(x):
#    1402     """Is `x` of a sparse array or sparse matrix type?
#    1403
#    1404     Parameters
#    (...)
#    1430     False
#    1431     """
#    1432     return isinstance(x, _spbase)
#
# KeyboardInterrupt:

# %%
nmi = normalized_mutual_info_score(labels, ai_labels)
print(nmi)
# Out:
# 0.5251232231881913
